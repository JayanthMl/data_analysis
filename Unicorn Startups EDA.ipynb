# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Startups.csv")
df.head()
# Out:
#    Unnamed: 0    Company Valuation ($B) Date Joined        Country  \
# 0           0  Bytedance           $140    4/7/2017          China
# 1           1     SpaceX         $100.3   12/1/2012  United States
# 2           2     Stripe            $95   1/23/2014  United States
# 3           3     Klarna          $45.6  12/12/2011         Sweden
# 4           4      Canva            $40    1/8/2018      Australia
#
#             City                      Industry  \
# 0        Beijing       Artificial intelligence
# 1      Hawthorne                         Other
# 2  San Francisco                       Fintech
# 3      Stockholm                       Fintech
# 4    Surry Hills  Internet software & services
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Institutional Venture Partners, Sequoia Capita...
# ...

# %%
#Checking for null values
pd.isnull(df).sum()
# Out:
# Unnamed: 0           0
# Company              0
# Valuation ($B)       0
# Date Joined          0
# Country              0
# City                15
# Industry             0
# Select Investors     1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        936 non-null    int64
#  1   Company           936 non-null    object
#  2   Valuation ($B)    936 non-null    object
#  3   Date Joined       936 non-null    object
#  4   Country           936 non-null    object
#  5   City              921 non-null    object
#  6   Industry          936 non-null    object
#  7   Select Investors  935 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 58.6+ KB

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0 Company Valuation ($B) Date Joined        Country  \
# count   936.000000     936            936         936            936
# unique         NaN     935            192         589             47
# top            NaN    Bolt             $1   7/13/2021  United States
# freq           NaN       2            225           8            477
# mean    467.500000     NaN            NaN         NaN            NaN
# std     270.344225     NaN            NaN         NaN            NaN
# min       0.000000     NaN            NaN         NaN            NaN
# 25%     233.750000     NaN            NaN         NaN            NaN
# 50%     467.500000     NaN            NaN         NaN            NaN
# 75%     701.250000     NaN            NaN         NaN            NaN
# max     935.000000     NaN            NaN         NaN            NaN
#
#                  City Industry                             Select Investors
# ...

# %%
sort_df = df.sort_values("Valuation ($B)", ascending = False).head(10)
sort_df
# Out:
#     Unnamed: 0       Company Valuation ($B) Date Joined        Country  \
# 2            2        Stripe            $95   1/23/2014  United States
# 53          53     OYO Rooms           $9.6   9/25/2018          India
# 45          45  ServiceTitan           $9.5  11/14/2018  United States
# 44          44    OutSystems           $9.5    6/5/2018  United States
# 46          46        HEYTEA          $9.28    7/1/2019          China
# 47          47           N26          $9.23   1/10/2019        Germany
# 48          48       Klaviyo           $9.2  11/17/2020  United States
# 49          49     Northvolt          $9.08   6/12/2019         Sweden
# 50          50        Tanium             $9   3/31/2015  United States
# 51          51     Chehaoduo             $9   3/12/2016          China
#
#              City                         Industry  \
# 2   San Francisco                          Fintech
# 53       Gurugram                           Travel
# ...
